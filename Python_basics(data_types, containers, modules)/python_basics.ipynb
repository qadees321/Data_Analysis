# %%
"""Task: Write a Python program to print “Python is Fun!” using a single print() statement."""

print("Python is Fun!")
# Out:
# Python is Fun!

# %%
"""Task: Print your name and age in a single line output."""

print("Muhammad Qadees", "18", sep=" : ")
# Out:
# Muhammad Qadees : 18

# %%
"""Task: Print the numbers 1, 2, 3, 4 separated by a Hash(#) using the sep parameter."""

print(1, 2, 3, 4, sep = "#")
# Out:
# 1#2#3#4

# %%
"""Task: Use the end parameter to print "Hello" and "World" on the same line with a space in
between."""

print("Hello","World", end=" ")
# Out:
# Hello World

# %%
"""Task: Print “Learning-Python-is-easy!” using sep and end parameters."""

print("Learning","Python","is", "easy", sep = "-", end="!")
# Out:
# Learning-Python-is-easy!

# %%
"""Task: Print the numbers 10, 20, 30 separated by a comma and a space (", "), and ensure the next
print statement starts on the same line."""

print(10, 20, 30, sep = ", ")
# Out:
# 10, 20, 30

# %%
"""Task: Write a program that prints your name, age and city on the same line, each separated by
the word "and"."""

print("Muhammad Qadees", "18", "Karachi", sep = " and ")
# Out:
# Muhammad Qadees and 18 and Karachi

# %%
"""Task: Use the print() function to output the following without using multiple print statements:
Welcome to Python. 
Let's learn together."""

print("Welcome to Python", "\nLet's learn together")
# Out:
# Welcome to Python
# Let's learn together

# %%
"""Task: What will be the output of the following code:
       a = 5
       a = 2.5
       print(a)
       print(type(a))"""

a = 5
a = 2.5
print(a)
print(type(a))
# Out:
# 2.5
# <class 'float'>

# %%
"""Task: What will be the output of the following code:
      value = "False"
      print(type(value))"""

value = "False"
print(type(value))
# Out:
# <class 'str'>

# %%
"""Task: What will be the data type of the value returned by input() and output of the following code?
      age = input("Enter your age: ")
      print(age + 5)"""

age = input("Enter your age: ")
print(type(age))
print(age + 5) ##It generates an error here of can only concatenate str (not "int") to str
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       3       print(age + 5)"""
#       4
#       5 age = input("Enter your age: ")
#       6 print(type(age))
# ----> 7 print(age + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
"""Task: Write Code:
      Ask the user to enter two numbers.
      Swap those and print """

num1 = int(input("Please enter first number: "))
num2 = int(input("Please enter second number: "))
print("Before swapping!")
print(f"First Number: {num1}, Second Number: {num2}")
num3 = num1
num1 = num2
num2 = num3
print("After swapping!")
print(f"First Number: {num1}, Second Number: {num2}")
# Out:
# Before swapping!
# First Number: 1, Second Number: 5
# After swapping!
# First Number: 5, Second Number: 1

# %%
"""Task: Create variables name and city with your name and city as values. Print both variables in a
single line. """

name = "Ashfaq Ahmad"
city = "Lahore"
print(name, city)
# Out:
# Ashfaq Ahmad Lahore

# %%
"""Task: Start with x = 5. Reassign x to 10. Print the final value of x."""

x = 5
x = 10
print(x)
# Out:
# 10

# %%
"""Task: Which of these variable names are valid in Python: my_var, 123_var, myVar1, your var? Use
all these variables and show output."""

my_var = "abcd" ##this variable name is valid in python
123_var = "act" ##this variable name is not valid in python, you can't start variable name with numbers
myVar1 = "testing" ##this variable name is valid in python
your var = "test" ##this variable name is not valid in python, you can't add space in between varaible name characters
# Out:
#   Cell In[30], line 5
#     123_var = "act" ##this variable name is not valid in python, you can't start variable name with numbers
#        ^
# SyntaxError: invalid decimal literal

# %%
"""Task: Swap two variables a = 10 and b = 5 without using a third variable."""

a = 10
b = 5
a = a - b
b = b + 5
print("After swapping!")
print(f"Value of A: {a}, Value of B: {b}")
# Out:
# After swapping!
# Value of A: 5, Value of B: 10

# %%
"""Task: Concatenate strings stored in two different variables first_name and second_name and print
result."""

first_name = "Ashafaq"
last_name = " Ahmad"
print(first_name + last_name)
# Out:
# Ashafaq Ahmad

# %%
"""Task: Use f-strings to print your bio and input function must be used."""

bio = input("Please enter your bio here: ")
print(f"The bio you entered is: {bio}")
# Out:
# The bio you entered is: Hi! My name is Muhammad Qadees

# %%
"""Task: Ask the user for their name, age, and city, then print a formatted sentence using format
method."""

name = input("Please enter your name: ")
age = int(input("Please enter your age: "))
city = input("Please enter your city: ")
sentence = "My name is {}, I am {} years old and I reside in {}".format(name,age,city)
print(sentence)
# Out:
# My name is Muhammad Qadees, I am 20 years old and I reside in Karachi

# %%
"""Task: Take input from user as product & cost then print output in following manner:
The Laptop costs $1200."""

product = input("Please enter the name of the product: ")
cost = int(input("Please enter the cost of the product: "))
print(f"The {product} costs ${cost}")
# Out:
# The Laptop costs $1200

# %%
"""Task: Take input from user as product & cost then print output in following manner:
The Laptop costs $1200."""

name = "Nusrat Fateh Ali Khan"
age = 65
city = "Faisalabad"

print("Name: ",name, end=" | ")
print("Age: ", age, end=" | ")      
print("City: ", city)
# Out:
# Name:  Nusrat Fateh Ali Khan | Age:  65 | City:  Faisalabad

# %%
"""Task: Write a program to print a countdown from 5 to 1, all on the same line, separated by spaces"""

print(5, 4, 3, 2, 1, sep=" ")
# Out:
# 5 4 3 2 1

# %%
"""Task: Write a program to take user’s email address using input function."""

email =  input("Please enter your input: ")
print("Your email address is: ", email)
# Out:
# Your email address is:  abcd@gmail.com

# %%
"""Task: Print the names of five programming languages separated by (->) :
Using single print statement
Using multiple print statement"""

print("Python","Java","SQL","C++","Golang", sep=" -> ")

print("Python", end=" -> ")
print("Java", end=" -> ")
print("SQL", end=" -> ")
print("C++", end=" -> ")
print("Golang")
# Out:
# Python -> Java -> SQL -> C++ -> Golang
# Python -> Java -> SQL -> C++ -> Golang

# %%
"""Task: Print 1, 2, 3, 4, 5] using single print statement"""

print(1,2,3,4,5, end="]")
# Out:
# 1 2 3 4 5]

# %%
"""Task: Create two variables, name and city, with your name and city as values and print both variables in a single line."""

name = "Nusrat Fateh Ali Khan"
city = "Lahore"
print(f'Name: {name}, City: {city}')
# Out:
# Name: Nusrat Fateh Ali Khan, City: Lahore

# %%
"""Task: We have four variables a = 5, b = 10, c = 3 and d = 6 swap the values of variable a & b and c & d."""

a = 5
b = 10
c = 3
d = 6
print("Before Swapping!")
print(f'A = {a}, B = {b}, C = {c}, D = {d}')

e = 0
e = a
a = b
b = e

i = 0
i = c
c = d
d = i
print("\nAfter Swapping!")
print(f'A = {a}, B = {b}, C = {c}, D = {d}')
# Out:
# Before Swapping!
# A = 5, B = 10, C = 3, D = 6
#
# After Swapping!
# A = 10, B = 5, C = 6, D = 3

# %%
"""Task: Ask the user for their name, age, and city and print the sentence in reverse order using
.format()
expected output: Lahore is where I live. 22 is my age. My name is Ali."""

name = input("Please enter your name: ")
age = int(input("Please enter your age: "))
city = input("Please enter your city: ")
reverse_sentence = "{} is where I live. {} is my age. My name is {}".format(city,age,name)
print(reverse_sentence)
# Out:
# Lahore is where I live. 22 is my age. My name is Ali

# %%
"""Task: Ask the user to input product and its price then generate a receipt using f-string:
expected output:"""

product = input("Please enter the name of the product: ")
price = int(input("Please enter the price of the product: "))
print(f"---------- Receipt ---------- \n{product}:      ${price} \n----------------------------- \nTotal:       ${price}")
# Out:
# ---------- Receipt ----------
# Laptop:      $1200
# -----------------------------
# Total:       $1200
